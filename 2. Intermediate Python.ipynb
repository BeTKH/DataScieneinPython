# %% [markdown]
# # CH-1: Basic Plots with Matplotlib
#
# DV is Very important in Data Analysis.
# Why?
#
#     ● Explore data
#     ● Report insights
#     ● Interpret the data
#     ● see the trend, general pattern ...etc
# There are many data visualization packages in python. Some are listed below:
#
# **Matplotlib**
#
#         Scatter plots
#         Bar charts and Histograms
#         Line plots
#         Pie charts
#         Stem plots
#         Contour plots
#         Quiver plots
#         Spectrograms
# **Seaborn**
#
# **ggplot**
#
# **Bokeh**
#
# **Plotly**
#
# **Pygal**
#
# **Altair**
#
# **Geoplotlib**
#
# **Gleam**
#
# **Missingno**
#
# **Leather**
#
# ## 1. Line Plot: for showing time depedent variable
#
# With matplotlib, you can create a bunch of different plots in Python.
#
# A general syntax:
#
#      import matplotlib.pyplot as plt
#      plt.plot(x,y)
#      plt.show()

# %%
import matplotlib.pyplot as plt

# %%
year = [1950, 1970, 1990, 2010]
pop = [2.519, 3.692, 5.263, 6.972]

# %%
plt.plot(year, pop)
plt.xlabel("Year")
plt.ylabel("Population")
plt.title("Year vs Population")
plt.grid(True)
plt.show()

# %% [markdown]
# ## 2. Scatter Plot
#
# For showing correlation between two variables.
#
#     import matplotlib.pyplot as plt
#     plt.scatter(x,y)
#     plt.show()

# %%
import matplotlib.pyplot as plt

# %%
year = [1950, 1970, 1990, 2010]
pop = [2.519, 3.692, 5.263, 6.972]

# %%
plt.scatter(year, pop)
plt.xlabel("Year")
plt.ylabel("Population")
plt.title("Year vs Population Scatter plot")
plt.yticks([2.519, 3.692, 5.263, 6.972], ["2B","3B","5B","6B"])
plt.show()

# the correlation clearly shows the pop increased with time

# %% [markdown]
# ## 3. Histograms
#
#     ● Get idea about distribution

# %%
import matplotlib.pyplot as plt

# %%
values = [0,0.6,1.4,1.6,2.2,2.5,2.6,3.2,3.5,3.9,4.2,6]

# %%
plt.hist(values, bins=3) #default bins equals 10
plt.show()

# %% [markdown]
# By default, **Python sets the number of bins to 10**.
#
# The number of `bins` is pretty important.
#
#     ● Too few bins will oversimplify reality and won't show you the details.
#     ● Too many bins will overcomplicate reality and won't show the bigger picture.

# %%
plt.hist(values, bins=5)
plt.show()

plt.clf()              #plt.clf() cleans it up again so you can start afresh

plt.hist(values, bins=20)
plt.show()

# %% [markdown]
# ## Customization
#
# Many options:
#
#     ● Different plot types
#     ● Many customizations
#
# Choice depends on:
#
#     ● Data
#     ● Story you want to tell

# %% [markdown]
# ## Labels
#
# To add x-axis and y-axis labels use the `xlabel()` and  `ylabel()` functions respectively.
#
# To add title use `title()` function.
#
# The functions are available in `matplotlib.pyplot`.

# %%
import matplotlib.pyplot as plt
gdp = [10000, 15000, 20000, 25000]
pop = [40, 55, 62, 74]


plt.xlabel('GDP [in USD]')
plt.ylabel('Life expectancy [in years]')
plt.title('World Development in 2007')
plt.xticks([10000, 15000, 20000, 25000], ["10B","15B","20T","25T"])
plt.plot(gdp, pop)
plt.grid()
plt.show()

# %%
import matplotlib.pyplot as plt
year = [1950, 1970, 1990, 2010]
pop = [2.519, 3.692, 5.263, 6.972]


plt.xlabel('GDP per Capita [in USD]')
plt.ylabel('Life Expectancy [in years]')
plt.title('World Development in 2007')

plt.scatter(year, pop)
plt.show()

plt.clf()    #plt.clf() cleans it up again so you can start afresh

plt.xlabel('GDP per Capita [in USD]')
plt.ylabel('Life Expectancy [in years]')
plt.title('World Development in 2007')
plt.plot(year, pop)
plt.show()

# %% [markdown]
# ## Ticks
#
# Segments on the axises (x-axis or y-axis).
#
#     e.g. plt.yticks([0,1,2], ["one","two","three"])

# %%
import matplotlib.pyplot as plt
import numpy as np

gdp = [974.5803384,
 5937.029525999998,
 6223.367465,
 4797.231267,
 12779.37964,
 34435.367439999995,
 36126.4927,
 29796.04834,
 1391.253792,
 33692.60508,
 1441.284873,
 3822.137084,
 7446.298803,
 12569.85177,
 9065.800825,
 10680.79282,
 1217.032994,
 430.0706916,
 1713.778686,
 2042.09524,
 36319.23501,
 706.016537,
 1704.063724,
 13171.63885,
 4959.114854,
 7006.580419,
 986.1478792,
 277.5518587,
 3632.557798,
 9645.06142,
 1544.750112,
 14619.222719999998,
 8948.102923,
 22833.30851,
 35278.41874,
 2082.4815670000007,
 6025.3747520000015,
 6873.262326000001,
 5581.180998,
 5728.353514,
 12154.08975,
 641.3695236000002,
 690.8055759,
 33207.0844,
 30470.0167,
 13206.48452,
 752.7497265,
 32170.37442,
 1327.60891,
 27538.41188,
 5186.050003,
 942.6542111,
 579.2317429999998,
 1201.637154,
 3548.3308460000007,
 39724.97867,
 18008.94444,
 36180.78919,
 2452.210407,
 3540.651564,
 11605.71449,
 4471.061906,
 40675.99635,
 25523.2771,
 28569.7197,
 7320.8802620000015,
 31656.06806,
 4519.461171,
 1463.249282,
 1593.06548,
 23348.139730000006,
 47306.98978,
 10461.05868,
 1569.331442,
 414.5073415,
 12057.49928,
 1044.770126,
 759.3499101,
 12451.6558,
 1042.581557,
 1803.151496,
 10956.99112,
 11977.57496,
 3095.7722710000007,
 9253.896111,
 3820.17523,
 823.6856205,
 944.0,
 4811.060429,
 1091.359778,
 36797.93332,
 25185.00911,
 2749.320965,
 619.6768923999998,
 2013.977305,
 49357.19017,
 22316.19287,
 2605.94758,
 9809.185636,
 4172.838464,
 7408.905561,
 3190.481016,
 15389.924680000002,
 20509.64777,
 19328.70901,
 7670.122558,
 10808.47561,
 863.0884639000002,
 1598.435089,
 21654.83194,
 1712.472136,
 9786.534714,
 862.5407561000002,
 47143.17964,
 18678.31435,
 25768.25759,
 926.1410683,
 9269.657808,
 28821.0637,
 3970.095407,
 2602.394995,
 4513.480643,
 33859.74835,
 37506.41907,
 4184.548089,
 28718.27684,
 1107.482182,
 7458.396326999998,
 882.9699437999999,
 18008.50924,
 7092.923025,
 8458.276384,
 1056.380121,
 33203.26128,
 42951.65309,
 10611.46299,
 11415.80569,
 2441.576404,
 3025.349798,
 2280.769906,
 1271.211593,
 469.70929810000007]

life_exp = [43.828,
 76.423,
 72.301,
 42.731,
 75.32,
 81.235,
 79.829,
 75.635,
 64.062,
 79.441,
 56.728,
 65.554,
 74.852,
 50.728,
 72.39,
 73.005,
 52.295,
 49.58,
 59.723,
 50.43,
 80.653,
 44.74100000000001,
 50.651,
 78.553,
 72.961,
 72.889,
 65.152,
 46.462,
 55.322,
 78.782,
 48.328,
 75.748,
 78.273,
 76.486,
 78.332,
 54.791,
 72.235,
 74.994,
 71.33800000000002,
 71.878,
 51.57899999999999,
 58.04,
 52.947,
 79.313,
 80.657,
 56.735,
 59.448,
 79.406,
 60.022,
 79.483,
 70.259,
 56.007,
 46.38800000000001,
 60.916,
 70.19800000000001,
 82.208,
 73.33800000000002,
 81.757,
 64.69800000000001,
 70.65,
 70.964,
 59.545,
 78.885,
 80.745,
 80.546,
 72.567,
 82.603,
 72.535,
 54.11,
 67.297,
 78.623,
 77.58800000000002,
 71.993,
 42.592,
 45.678,
 73.952,
 59.44300000000001,
 48.303,
 74.241,
 54.467,
 64.164,
 72.801,
 76.195,
 66.803,
 74.543,
 71.164,
 42.082,
 62.069,
 52.90600000000001,
 63.785,
 79.762,
 80.204,
 72.899,
 56.867,
 46.859,
 80.196,
 75.64,
 65.483,
 75.53699999999998,
 71.752,
 71.421,
 71.688,
 75.563,
 78.098,
 78.74600000000002,
 76.442,
 72.476,
 46.242,
 65.528,
 72.777,
 63.062,
 74.002,
 42.56800000000001,
 79.972,
 74.663,
 77.926,
 48.159,
 49.339,
 80.941,
 72.396,
 58.556,
 39.613,
 80.884,
 81.70100000000002,
 74.143,
 78.4,
 52.517,
 70.616,
 58.42,
 69.819,
 73.923,
 71.777,
 51.542,
 79.425,
 78.242,
 76.384,
 73.747,
 74.249,
 73.422,
 62.698,
 42.38399999999999,
 43.487]
pop = [31.889923, 3.600523, 33.333216, 12.420476, 40.301927, 20.434176, 8.199783, 0.708573, 150.448339, 10.392226, 8.078314, 9.119152, 4.552198, 1.639131, 190.010647, 7.322858, 14.326203, 8.390505, 14.131858, 17.696293, 33.390141, 4.369038, 10.238807, 16.284741, 1318.683096, 44.22755, 0.71096, 64.606759, 3.80061, 4.133884, 18.013409, 4.493312, 11.416987, 10.228744, 5.46812, 0.496374, 9.319622, 13.75568, 80.264543, 6.939688, 0.551201, 4.906585, 76.511887, 5.23846, 61.083916, 1.454867, 1.688359, 82.400996, 22.873338, 10.70629, 12.572928, 9.947814, 1.472041, 8.502814, 7.483763, 6.980412, 9.956108, 0.301931, 1110.396331, 223.547, 69.45357, 27.499638, 4.109086, 6.426679, 58.147733, 2.780132, 127.467972, 6.053193, 35.610177, 23.301725, 49.04479, 2.505559, 3.921278, 2.012649, 3.193942, 6.036914, 19.167654, 13.327079, 24.821286, 12.031795, 3.270065, 1.250882, 108.700891, 2.874127, 0.684736, 33.757175, 19.951656, 47.76198, 2.05508, 28.90179, 16.570613, 4.115771, 5.675356, 12.894865, 135.031164, 4.627926, 3.204897, 169.270617, 3.242173, 6.667147, 28.674757, 91.077287, 38.518241, 10.642836, 3.942491, 0.798094, 22.276056, 8.860588, 0.199579, 27.601038, 12.267493, 10.150265, 6.144562, 4.553009, 5.447502, 2.009245, 9.118773, 43.997828, 40.448191, 20.378239, 42.292929, 1.133066, 9.031088, 7.554661, 19.314747, 23.174294, 38.13964, 65.068149, 5.701579, 1.056608, 10.276158, 71.158647, 29.170398, 60.776238, 301.139947, 3.447496, 26.084662, 85.262356, 4.018332, 22.211743, 11.746035, 12.311143]

np_pop = np.array(pop)

plt.scatter(gdp, life_exp, s = np_pop)
# Previous customizations
plt.xscale('log') 
plt.xlabel('GDP per Capita [in USD]')
plt.ylabel('Life Expectancy [in years]')
plt.title('World Development in 2007')
plt.xticks([1000, 10000, 100000],['1k', '10k', '100k'])
plt.grid()
plt.show()

# %% [markdown]
# ### color
#
#     dict = {
#         'Asia':'red',
#         'Europe':'green',
#         'Africa':'blue',
#         'Americas':'yellow',
#         'Oceania':'black'
#     }

# %% [markdown]
# # CH-2: Dictionaries and Data Structures
#
# ### Motivation for dictionaries
#
# To see why dictionaries are useful, have a look at the two lists below.
#
#     countries contains the names of some European countries.
#     capitals lists the corresponding names of their capital.

# %%
countries = ['spain', 'france', 'germany', 'norway']
capitals = ['madrid', 'paris', 'berlin', 'oslo']

# Get index of 'germany': ind_ger
ind_ger = countries.index('germany')

# Use ind_ger to print out capital of Germany
print(capitals[ind_ger])
# Out:
# berlin

# %% [markdown]
# Using dictionaries however,the same goal can be achived more effectively as follows:
#
#     my_dict = {
#        "key1":"value1",
#        "key2":"value2",
#     }

# %%
europe = {
    'spain':'madrid',
    'france':'paris',
    'germany':'berlin',
    'norway':'oslo'
}

print(europe['germany'])
print(europe['norway'])
# Out:
# berlin
# oslo

# %% [markdown]
# #### Access dictionary
#
# If the keys of a dictionary are chosen wisely, accessing the values in a dictionary is easy and intuitive.

# %%
# Print out the keys in europe

print(europe.keys())
print(europe.values())
# Out:
# dict_keys(['Germany', 'France', 'Sweden', 'Norway'])
# dict_values(['Berlin', 'Paris', 'Stockholm', 'Oslo'])

# %% [markdown]
# #### Dictionary Manipulation
#
# If you know how to access a dictionary, you can also **assign a new value** to it. To add a new key-value pair to europe you can use something like this:
#
#     europe['iceland'] = 'reykjavik'

# %%
# Definition of dictionary
europe = {'spain':'madrid', 'france':'paris', 'germany':'berlin', 'norway':'oslo' }

# Add italy to europe
europe['italy'] = 'rome'

# in checks for the key but not the value
print('italy' in europe)

# returns false to the value
print('rome' in europe)
# Out:
# True
# False

# %%
# Add poland to europe
europe['poland'] = 'warsaw'

# Print europe
print(europe)
# Out:
# {'spain': 'madrid', 'france': 'paris', 'germany': 'berlin', 'norway': 'oslo', 'italy': 'rome', 'poland': 'warsaw'}

# %% [markdown]
# We can also update values of the dictionary.

# %%
# Definition of dictionary
europe = {'spain':'madrid', 'france':'paris', 'germany':'bonn',
          'norway':'oslo', 'italy':'rome', 'poland':'warsaw',
          'australia':'vienna' }

# Update capital of germany

europe['germany']='berlin'

# Remove australia
del europe['australia']

# Print europe
print(europe)
# Out:
# {'spain': 'madrid', 'france': 'paris', 'germany': 'berlin', 'norway': 'oslo', 'italy': 'rome', 'poland': 'warsaw'}

# %% [markdown]
# ### Nested Dictionaries
#
# Dictionaries can contain **key:value** pairs where the values are again **dictionaries**.
#
# It's perfectly possible to **chained square brackets** to select elements.
#
#     Example: To fetch the population for Spain from europe, for example, you need:
#
#         europe['spain']['population']

# %%
# Dictionary of dictionaries
europe = { 'spain': { 'capital':'madrid', 'population':46.77 },
           'france': { 'capital':'paris', 'population':66.03 },
           'germany': { 'capital':'berlin', 'population':80.62 },
           'norway': { 'capital':'oslo', 'population':5.084 } }


# Print out the capital of France

print(europe['france']['capital'])
print(europe['france']['population'])
# Out:
# paris
# 66.03

# %%
# Create sub-dictionary data
data = {'capital':'rome','population':59.83}

# Add data to europe under key 'italy'
europe['italy'] = data

# Print europe
print(europe)
# Out:
# {'spain': {'capital': 'madrid', 'population': 46.77}, 'france': {'capital': 'paris', 'population': 66.03}, 'germany': {'capital': 'berlin', 'population': 80.62}, 'norway': {'capital': 'oslo', 'population': 5.084}, 'italy': {'capital': 'rome', 'population': 59.83}}

# %% [markdown]
# ### Dictionary to DataFrame
#
# `Pandas` is:
#
#     an open source library
#
#     PROVIDES high-performance
#
#     easy-to-use data structures and data analysis tools for Python.
#
# The **DataFrame** is one of `Pandas'` most important data structures. It's basically **a way to store tabular data** where you can label the `rows` and the `columns`.

# %% [markdown]
# ### Building a DataFrame is from a dictionary
#
# We can build a DF manually when our DATA SET IS SMALL ENOUGH otherwise we need to create a DF by importing a data from a **CSV** file stored in a local storage.
#
# In case of very huge data set which we can't store on our local storage there are other techniques which will be covered on another tutorial.
#
# when we build a DataFrame from a dictionary:
#
#     Key's become column lebel
#
#     values become observations

# %%
# Pre-defined lists

names = ['United States', 'Australia', 'Japan', 'India', 'Russia', 'Morocco', 'Egypt']
dr =  [True, False, False, False, True, True, True]
cpc = [809, 731, 588, 18, 200, 70, 45]

# Import pandas as pd
import pandas as pd

# Create dictionary my_dict with three key:value pairs: my_dict
my_dict = {
            'country': names   , 
            'drives_right': dr , 
            "cars_per_cap": cpc  }

# Build a DataFrame cars from my_dict: cars

cars = pd.DataFrame(my_dict)

# Print cars
cars
# Out:
#          country  drives_right  cars_per_cap
# 0  United States          True           809
# 1      Australia         False           731
# 2          Japan         False           588
# 3          India         False            18
# 4         Russia          True           200
# 5        Morocco          True            70
# 6          Egypt          True            45

# %% [markdown]
# ### row lebeling
#
# As we can see `row labels` (i.e. the labels for the different observations) were automatically set to integers from 0 up to 6?
#
# We can specify the row labels of the cars DataFrame manually as follows:

# %%
print(cars.index)
# Out:
# RangeIndex(start=0, stop=7, step=1)

# %%
# Definition of row_labels
row_labels = ['US', 'AUS', 'JPN', 'IN', 'RU', 'MOR', 'EG']

# Specify row labels of cars
cars.index = row_labels

# Print cars again
cars
# Out:
#            country  drives_right  cars_per_cap
# US   United States          True           809
# AUS      Australia         False           731
# JPN          Japan         False           588
# IN           India         False            18
# RU          Russia          True           200
# MOR        Morocco          True            70
# EG           Egypt          True            45

# %% [markdown]
# ### CSV to DataFrame
#
# Putting data in a dictionary and then building a DataFrame works, **but it's not very efficient.**
#
# **What if you're dealing with millions of observations?**
#
# In those cases, _If the data is typically available as files with a **regular structure or structured format**_.
#
# One of those file types(file type with regular structure is) is the CSV file, which is short for `"comma-separated values"`.
#
#
#
#
# To import CSV data into Python as a Pandas DataFrame you can use `read_csv()`.

# %%
# Import pandas as pd
import pandas as pd

# %%
# Import the cars.csv data: cars
brics = pd.read_csv('brics.csv')

# Print out cars
brics
# Out:
#   Unnamed: 0       country    capital    area  population
# 0         BR        Brazil   Brasilia   8.516      200.40
# 1         RU        Russia     Moscow  17.100      143.50
# 2         IN         India  New Delhi   3.286     1252.00
# 3         CH         China    Beijing   9.597     1357.00
# 4         SA  South Africa   Pretoria   1.221       52.98

# %% [markdown]
# ### Set an index to the first column
#
# index_col = 0

# %%
# ISet an index to the first column index_col = 0

brics = pd.read_csv('brics.csv',index_col = 0)

# Print out cars
brics
# Out:
#          country    capital    area  population
# BR        Brazil   Brasilia   8.516      200.40
# RU        Russia     Moscow  17.100      143.50
# IN         India  New Delhi   3.286     1252.00
# CH         China    Beijing   9.597     1357.00
# SA  South Africa   Pretoria   1.221       52.98

# %%
import pandas as pds

carss = pds.read_csv('cars2.csv', index_col=0)
carss
# Out:
#            country  drives_right
# US   United States          True
# AUS      Australia         False
# JPN          Japan         False
# IN           India         False
# RU          Russia          True
# MOR        Morocco          True
# EG           Egypt          True

# %% [markdown]
# ### Index and Select Data
#
#
# There are different ways to index and select data from the data frames.
#
#     1. Square brackets
#     2. Advanced methods
#         I. loc
#         II. iloc
#
# #### 1. Square brackets
#
# We index and select Pandas DataFrames in **many different ways**.
#
# The simplest, but not the most powerful way, is to use square brackets.
#
# #### selecting columns using square brackets
#
# Syntax to select columns:
#
#     df['column lebel']   --> Returns Pandas Series
#     df[['column lebel']] --> Returns Pandas DF
#     df[['column lebel1','column lebel2', ...]] --> we can also pass list of  col lebels to sel multiple columns

# %%
# Import cars data
import pandas as pd
brics = pd.read_csv('brics.csv', index_col = 0)
brics
# Out:
#          country    capital    area  population
# BR        Brazil   Brasilia   8.516      200.40
# RU        Russia     Moscow  17.100      143.50
# IN         India  New Delhi   3.286     1252.00
# CH         China    Beijing   9.597     1357.00
# SA  South Africa   Pretoria   1.221       52.98

# %%
# Print out country column as Pandas Series
brics["country"]
# Out:
# BR          Brazil
# RU          Russia
# IN           India
# CH           China
# SA    South Africa
# Name: country, dtype: object

# %%
print(type(brics["country"]))
# Out:
# <class 'pandas.core.series.Series'>

# %%
# Print out country column as Pandas DataFrame
brics[["country"]]
# Out:
#          country
# BR        Brazil
# RU        Russia
# IN         India
# CH         China
# SA  South Africa

# %%
print(type(brics[["country"]]))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
# we can also pass list of  col lebels to sel multiple columns
# Print out DataFrame with country and capital columns
brics[["country", "capital"]]
# Out:
#          country    capital
# BR        Brazil   Brasilia
# RU        Russia     Moscow
# IN         India  New Delhi
# CH         China    Beijing
# SA  South Africa   Pretoria

# %% [markdown]
# #### selecting rows using square brackets
#
# We can use sq, brackets to  `to get rows or observations` from a DataFrame.
#
# The `result` is another DataFrame containing `only the rows you specified`.
#
# **PAY ATTENTION!**:
#
#     You can only select rows using square brackets if you specify a slice, like 0:4.
#
#     Also, you're using the integer indexes of the rows here, not the row labels!

# %%
# Import cars data
import pandas as pd
brics = pd.read_csv('brics.csv', index_col = 0)
brics
# Out:
#          country    capital    area  population
# BR        Brazil   Brasilia   8.516      200.40
# RU        Russia     Moscow  17.100      143.50
# IN         India  New Delhi   3.286     1252.00
# CH         China    Beijing   9.597     1357.00
# SA  South Africa   Pretoria   1.221       52.98

# %%
# Print out first 3 observations of the DF
brics[['country', 'capital']][1:3]
# Out:
#    country    capital
# RU  Russia     Moscow
# IN   India  New Delhi

# %%
# If we don't specify the col selection of DF, it will select all columns by default
brics[2:]
# Out:
#          country    capital   area  population
# IN         India  New Delhi  3.286     1252.00
# CH         China    Beijing  9.597     1357.00
# SA  South Africa   Pretoria  1.221       52.98

# %% [markdown]
# ### 2. Advanced methods  { loc &  iloc }
#
#
#
# With `loc` and `iloc` you can do practically any data selection operation on DataFrames you can think of.
#
# `loc` is **label-based**, which means that you have to `specify rows and columns` based on their `row and column labels`.
#
#
# `iloc` is integer **index based**, so you have to `specify rows and columns` by their `integer index` like we did in the previous exercise (square brackets).

# %% [markdown]
# ### Row Access loc - using row label
#
# general syntax:
#
#
# **df.loc[  ["rowlebel1", "rowlebel1", ...]  , ["col_leb1", "col_leb2", ...]  ]**

# %%
import pandas as pd
brics = pd.read_csv('brics.csv', index_col = 0)
brics
# Out:
#          country    capital    area  population
# BR        Brazil   Brasilia   8.516      200.40
# RU        Russia     Moscow  17.100      143.50
# IN         India  New Delhi   3.286     1252.00
# CH         China    Beijing   9.597     1357.00
# SA  South Africa   Pretoria   1.221       52.98

# %%
#print Russia row as Pandas Series
print(brics.loc["RU"], "\n\n")

#print Russia row as DataFrame
print(brics.loc[["RU"]])
# Out:
# country       Russia
# capital       Moscow
# area            17.1
# population     143.5
# Name: RU, dtype: object
#
#
#    country capital  area  population
# RU  Russia  Moscow  17.1       143.5

# %% [markdown]
# ### Multiple-Row Access loc - separate multiple row lebels by comma

# %%
import pandas as pd
brics = pd.read_csv('brics.csv', index_col = 0)

brics.loc[["RU", "IN", "CH"]]
# Out:
#    country    capital    area  population
# RU  Russia     Moscow  17.100       143.5
# IN   India  New Delhi   3.286      1252.0
# CH   China    Beijing   9.597      1357.0

# %% [markdown]
# ### Row & Column loc

# %%
# Row & Column loc

brics.loc[["RU", "IN", "CH"], ["country", "capital"]]
# Out:
#    country    capital
# RU  Russia     Moscow
# IN   India  New Delhi
# CH   China    Beijing

# %% [markdown]
# ##### select all rows

# %%
# select all rows ---> replace the sq. bracket with :

brics.loc[:, ["country", "capital"]]
# Out:
#          country    capital
# BR        Brazil   Brasilia
# RU        Russia     Moscow
# IN         India  New Delhi
# CH         China    Beijing
# SA  South Africa   Pretoria

# %%
# select all rows and columns---> replace the sq. brackets with :

brics.loc[: , :]  #same as brics
# Out:
#          country    capital    area  population
# BR        Brazil   Brasilia   8.516      200.40
# RU        Russia     Moscow  17.100      143.50
# IN         India  New Delhi   3.286     1252.00
# CH         China    Beijing   9.597     1357.00
# SA  South Africa   Pretoria   1.221       52.98

# %%
# does element wise comaprison and gives us a DF

brics.loc[: , :] == brics
# Out:
#     country  capital  area  population
# BR     True     True  True        True
# RU     True     True  True        True
# IN     True     True  True        True
# CH     True     True  True        True
# SA     True     True  True        True

# %% [markdown]
# ### Row Access iloc
#
# Generic syntax:
#
#     df.iloc[[rw_indx1,rw_indx2,...], [col_indx1, col_indx2, ...]]

# %%
brics
# Out:
#          country    capital    area  population
# BR        Brazil   Brasilia   8.516      200.40
# RU        Russia     Moscow  17.100      143.50
# IN         India  New Delhi   3.286     1252.00
# CH         China    Beijing   9.597     1357.00
# SA  South Africa   Pretoria   1.221       52.98

# %%
# df.iloc[[rw_indx1,rw_indx2,...], [col_indx1, col_indx2, ...]]

brics.iloc[[0,1,2],[1,2]]
# Out:
#       capital    area
# BR   Brasilia   8.516
# RU     Moscow  17.100
# IN  New Delhi   3.286

# %%
brics.iloc[[1]] # is same as brics.loc[["RU"]]
# Out:
#    country capital  area  population
# RU  Russia  Moscow  17.1       143.5

# %%
brics.loc[["RU"]]
# Out:
#    country capital  area  population
# RU  Russia  Moscow  17.1       143.5

# %% [markdown]
# ### Multiple Row Access iloc

# %%
 brics.iloc[[1,2,3]] 
    
# same as:

#brics.loc[["RU", "IN", "CH"]]
# Out:
#    country    capital    area  population
# RU  Russia     Moscow  17.100       143.5
# IN   India  New Delhi   3.286      1252.0
# CH   China    Beijing   9.597      1357.0

# %% [markdown]
# ### Row & Column iloc

# %%
brics.iloc[[1,2,3], [0, 1]] 

# smae as:

#brics.loc[["RU", "IN", "CH"], ["country", "capital"]]
# Out:
#    country    capital
# RU  Russia     Moscow
# IN   India  New Delhi
# CH   China    Beijing

# %% [markdown]
# Note:
#
# **brics.iloc[ , [0, 1]]**
#
# `thows an error:`as long as we use the middle coma we must specify how we access the rows

# %%
brics.iloc[:, [0,1]] 

# same as:
#brics.loc[:, ["country", "capital"]]
# Out:
#          country    capital
# BR        Brazil   Brasilia
# RU        Russia     Moscow
# IN         India  New Delhi
# CH         China    Beijing
# SA  South Africa   Pretoria

# %% [markdown]
# ### Exercises

# %%
# Import cars data
import pandas as pd
cars = pd.read_csv('cars.csv', index_col = 0)
cars
# Out:
#      cars_per_cap        country  drives_right
# US            809  United States          True
# AUS            31      Australia         False
# JPN           588          Japan         False
# IN             18          India         False
# RU            200         Russia          True
# MOR            70        Morocco          True
# EG             45          Egypt          True

# %%
# Print out observation for Japan as a Series
cars.loc["JPN"]
# OR
# print(cars.iloc[2])
# Out:
# cars_per_cap      588
# country         Japan
# drives_right    False
# Name: JPN, dtype: object

# %%
# observations for Australia and Egypt as a DataFrame

cars.loc[["AUS", "EG"]]

# OR
#print(cars.iloc[[1,6]])
# Out:
#      cars_per_cap    country  drives_right
# AUS            31  Australia         False
# EG             45      Egypt          True

# %%
cars
# Out:
#      cars_per_cap        country  drives_right
# US            809  United States          True
# AUS            31      Australia         False
# JPN           588          Japan         False
# IN             18          India         False
# RU            200         Russia          True
# MOR            70        Morocco          True
# EG             45          Egypt          True

# %%
# Print out drives_right value of Morocco
cars.loc[["MOR"],["drives_right"]]
# Out:
#      drives_right
# MOR          True

# %%
# Print sub-DataFrame, 
# containing the observations for Russia and Morocco 
# and the columns country and drives_right

cars.loc[["RU","MOR"]  ,  ["country","drives_right"]]

#OR
#print(cars.iloc[[4,5],[1,2]])
# Out:
#      country  drives_right
# RU    Russia          True
# MOR  Morocco          True

# %%
cars
# Out:
#      cars_per_cap        country  drives_right
# US            809  United States          True
# AUS            31      Australia         False
# JPN           588          Japan         False
# IN             18          India         False
# RU            200         Russia          True
# MOR            70        Morocco          True
# EG             45          Egypt          True

# %%
# Print out drives_right column as Series
cars.loc[: , "drives_right"]

# OR
# print(cars.iloc[: , [2]])
# Out:
# US      True
# AUS    False
# JPN    False
# IN     False
# RU      True
# MOR     True
# EG      True
# Name: drives_right, dtype: bool

# %%
# Print out cars_per_cap and drives_right as DataFrame
cars.loc[:, ["cars_per_cap", "drives_right"]]

#OR
#print(cars.iloc[:, [0, 2]])
# Out:
#      cars_per_cap  drives_right
# US            809          True
# AUS            31         False
# JPN           588         False
# IN             18         False
# RU            200          True
# MOR            70          True
# EG             45          True

# %% [markdown]
# # CH-3  Operators and Conditional Satements
#
# ## 3. 1. Comparison operators
#
# show how Python values relate
#
# Comparion Operators:
#
#     1. < strictly less than
#     2. <= less than or equal
#     3. > strictly greater than
#     4. >= greater than or equal
#     5. == equal
#     6. != not equa
#
# Different types of comparisons:
#
#     Numeric Comparisons
#
#     Other Comparisons
#
# `Result` of Comapriosn is always `Boolean`
#
# #### Equality
#
# To check if two Python values, or variables, are equal you can use `==`.
#
# `To check for inequality`, you need `!=`.
#
# example:

# %%
2 == (1 + 1)
# Out:
# True

# %%
"intermediate" != "python"
# Out:
# True

# %%
True != False
# Out:
# True

# %%
"Python" != "python"
# Out:
# True

# %%
# Comparison of booleans
True == False

# Comparison of integers
-5*15 != 75

# Comparison of strings
"pyscript" == "PyScript"

# Compare a boolean with an integer
True == 1
# Out:
# True

# %% [markdown]
# ### Greater and less than

# %%
# Comparison of integers
x = -3 * 6
print(x >= -10)
# Out:
# False

# %%
# Comparison of strings
y = "test"
print("test" <= y)

print('a'>'1')
# Out:
# True
# True

# %%
# Comparison of booleans
print(True > False)
# Out:
# True

# %% [markdown]
# for `string comparison`, Python determines the relationship based on `alphabetical order`

# %%
print('apple'>'cow')
# Out:
# False

# %% [markdown]
# ### Compare arrays

# %%
# Create arrays
import numpy as np
my_house = np.array([18.0, 20.0, 10.75, 9.50])
your_house = np.array([14.0, 24.0, 14.25, 9.0])

# %%
# my_house greater than or equal to 18
print(my_house >= 18)

# my_house less than your_house
print(my_house < your_house)
# Out:
# [ True  True False False]
# [False  True  True False]

# %% [markdown]
# ## 3.2 Boolean Operators
#
#
# A boolean is either 1 or 0, True or False.
#
# The boolean operators are `and`, `or` and `not`.
#
# We can combine these booleans to perform more advanced queries on your data.

# %%
# Define variables
my_kitchen = 18.0
your_kitchen = 14.0

# my_kitchen bigger than 10 and smaller than 18?
print(my_kitchen > 10 and my_kitchen <18)
# Out:
# False

# %%
# my_kitchen smaller than 14 or bigger than 17?
print(my_kitchen > 17 or my_kitchen <14)
# Out:
# True

# %%
# Double my_kitchen smaller than triple your_kitchen?
print((2 *my_kitchen) < (3*your_kitchen))
# Out:
# True

# %% [markdown]
# ### Boolean operators with Numpy
#
# The operational operators like < and >= work with Numpy arrays `out of the box`.
#
# Unfortunately, the boolean operators and, or, and `not DO NOT WORK` with Numpy arrays `out of the box`.
#
# Therefore:
#
# We use `Numpy logical opetators`.
#
#     These are:
#
#     i. np.logical_and(),
#
#     ii. np.logical_or() and
#
#     iii. np.logical_not().
#
# Here's an example on the my_house and your_house arrays from before to give you an idea:
#
# `example:`
#
#     np.logical_and(my_house > 13, your_house < 15)

# %%
# Create arrays
import numpy as np
my_house = np.array([18.0, 20.0, 10.75, 9.50])
your_house = np.array([14.0, 24.0, 14.25, 9.0])

print(my_house > 18.5)
print(my_house < 10)
# Out:
# [False  True False False]
# [False False False  True]

# %%
# my_house greater than 18.5 OR smaller than 10
print(np.logical_or(my_house > 18.5, my_house < 10))
# Out:
# [False  True False  True]

# %%
# my_house greater than 18.5 and smaller than 10
print(np.logical_and(my_house > 18.5, my_house < 10))
# Out:
# [False False False False]

# %% [markdown]
# ## 3.3 Conditional Statements
#
# ### if

# %%
# Define variables
room = "kit"
area = 14.0

# if statement for room
if room == "kit" :
    print("looking around in the kitchen.")

# if statement for area
if area >15:
    print("big place!")
# Out:
# looking around in the kitchen.

# %% [markdown]
# ### else

# %%
# Define variables
room = "kit"
area = 14.0

# if-else construct for room
if room == "kit" :
    print("looking around in the kitchen.")
else :
    print("looking around elsewhere.")

# if-else construct for area
if area > 15 :
    print("big place!")
else:
    print("pretty small.")
# Out:
# looking around in the kitchen.
# pretty small.

# %% [markdown]
# ### elif

# %%
# Define variables
room = "bed"
area = 14.0

# if-elif-else construct for room
if room == "kit" :
    print("looking around in the kitchen.")
elif room == "bed":
    print("looking around in the bedroom.")
else :
    print("looking around elsewhere.")

# if-elif-else construct for area
if area > 15 :
    print("big place!")
elif area > 10:
    print("medium size, nice!")
else :
    print("pretty small.")
# Out:
# looking around in the bedroom.
# medium size, nice!

# %% [markdown]
# ### 3.4. Knowledge Application: Filtering Pandas DataFrame
#
#
# **EXERCISES-1**. Select countries with area over 8 million km^2 from brics.csv
#
# Steps:
#
#     ● import pandas and the csv file
#
#     ● Select the area column
#
#     ● Do comparison on area column
#
#     ● Use result to select countries

# %%
import pandas as pd
brics = pd.read_csv("brics.csv", index_col = 0)
brics
# Out:
#          country    capital    area  population
# BR        Brazil   Brasilia   8.516      200.40
# RU        Russia     Moscow  17.100      143.50
# IN         India  New Delhi   3.286     1252.00
# CH         China    Beijing   9.597     1357.00
# SA  South Africa   Pretoria   1.221       52.98

# %%
#Select the area column
brics.loc[:, "area"]
# Out:
# BR     8.516
# RU    17.100
# IN     3.286
# CH     9.597
# SA     1.221
# Name: area, dtype: float64

# %%
# Do comparison on area column
brics["area"] > 8
# Out:
# BR     True
# RU     True
# IN    False
# CH     True
# SA    False
# Name: area, dtype: bool

# %%
is_huge = brics["area"] > 8

# %%
# Subset DF, select the countries

brics[is_huge]
# Out:
#    country   capital    area  population
# BR  Brazil  Brasilia   8.516       200.4
# RU  Russia    Moscow  17.100       143.5
# CH   China   Beijing   9.597      1357.0

# %% [markdown]
# **EXERCISE-2**. Select countries with area over 8 million km^2 **and** below 10 km^2 from brics.csv

# %%
import numpy as np
import pandas as pd

brics = pd.read_csv("brics.csv", index_col = 0)
brics
# Out:
#          country    capital    area  population
# BR        Brazil   Brasilia   8.516      200.40
# RU        Russia     Moscow  17.100      143.50
# IN         India  New Delhi   3.286     1252.00
# CH         China    Beijing   9.597     1357.00
# SA  South Africa   Pretoria   1.221       52.98

# %%
islarge = np.logical_and(brics["area"] > 8, brics["area"] < 10)

# %%
brics[islarge]
# Out:
#    country   capital   area  population
# BR  Brazil  Brasilia  8.516       200.4
# CH   China   Beijing  9.597      1357.0

# %% [markdown]
# **EXERCISE-3**
#
# ### Driving right (1)
#
# From cars dataset, containing the cars per 1000 people (cars_per_cap) and whether people drive right (drives_right) for different countries (country), import the data in CSV format into Python as a DataFrame.
#
# Filter observations from a DataFrame based on boolean arrays.
#
#
# Let's start simple and try to find all observations in cars where drives_right is True.
#
# drives_right is a boolean column, so you'll have to extract `it as a Series` and then use this boolean Series to select observations from cars.

# %%
# Import cars data
import pandas as pd
cars = pd.read_csv('cars.csv', index_col = 0)
cars
# Out:
#      cars_per_cap        country  drives_right
# US            809  United States          True
# AUS            31      Australia         False
# JPN           588          Japan         False
# IN             18          India         False
# RU            200         Russia          True
# MOR            70        Morocco          True
# EG             45          Egypt          True

# %%
# Extract drives_right column as Series: dr

dr = cars.loc[: , "drives_right"]
print(dr)
# Out:
# US      True
# AUS    False
# JPN    False
# IN     False
# RU      True
# MOR     True
# EG      True
# Name: drives_right, dtype: bool

# %%
# Use dr to subset cars: sel
sel = cars[dr]

# %%
# Print sel

sel
# Out:
#      cars_per_cap        country  drives_right
# US            809  United States          True
# RU            200         Russia          True
# MOR            70        Morocco          True
# EG             45          Egypt          True

# %% [markdown]
# **EXERCISE-4.**
#
# `Driving right (2)`
#
# The code in the previous example worked fine, but you actually unnecessarily created a new variable dr.
#
# You can achieve the same result without this intermediate variable.
#
# Put the code that computes dr straight into the square brackets that select observations from cars.

# %%
# Import cars data
import pandas as pd
cars = pd.read_csv('cars.csv', index_col = 0)

# Convert code to a one-liner
sel = cars[cars['drives_right']]

# Print sel
sel
# Out:
#      cars_per_cap        country  drives_right
# US            809  United States          True
# RU            200         Russia          True
# MOR            70        Morocco          True
# EG             45          Egypt          True

# %% [markdown]
# **EXERCISE 5**
#
# `Cars per capita (1)`
#
#
# Let's stick to the cars data some more. This time you want to find out which countries have a high cars per capita figure. In other words, in which countries do many people have a car, or maybe multiple cars.
#
# Similar to the previous example, you'll want to `build up a boolean Series, that you can then use to subset the cars DataFrame` to select certain observations. If you want to do this in a one-liner, that's perfectly fine!

# %%
# Import cars data
import pandas as pd
import numpy as np

cars = pd.read_csv('cars.csv', index_col = 0)
cars
# Out:
#      cars_per_cap        country  drives_right
# US            809  United States          True
# AUS            31      Australia         False
# JPN           588          Japan         False
# IN             18          India         False
# RU            200         Russia          True
# MOR            70        Morocco          True
# EG             45          Egypt          True

# %%
# Create car_maniac: observations that have a cars_per_cap over 500

cpc = cars.loc[: , "cars_per_cap"]

#create pd.series which can be used to subset the dataframe
many_cars = cpc > 500

print(many_cars)
print()
print(type(many_cars))
# Out:
# US      True
# AUS    False
# JPN     True
# IN     False
# RU     False
# MOR    False
# EG     False
# Name: cars_per_cap, dtype: bool
#
# <class 'pandas.core.series.Series'>

# %%
# Use many_cars to subset cars, Store the result as car_maniac.

car_manic = cars[many_cars]

# %%
car_manic
# Out:
#      cars_per_cap        country  drives_right
# US            809  United States          True
# JPN           588          Japan         False

# %% [markdown]
# **EXERCISE-6**
#
# `Cars per capita (2)`
#
# Remember about:
#
#     np.logical_and(),
#     np.logical_or() and
#     np.logical_not(), the Numpy variants of the and, or and not operators?
#
# You can also use them on Pandas Series to do more advanced filtering operations.
#
# Take this example that selects the observations that have a cars_per_cap between 10 and 80.
#
# Try out these lines of code step by step to see what's happening.
#
#     cpc = cars['cars_per_cap']
#     between = np.logical_and(cpc > 10, cpc < 80)
#     medium = cars[between]

# %%
# Import cars data
import pandas as pd
import numpy as np

cars = pd.read_csv('cars.csv', index_col = 0)
cars
# Out:
#      cars_per_cap        country  drives_right
# US            809  United States          True
# AUS            31      Australia         False
# JPN           588          Japan         False
# IN             18          India         False
# RU            200         Russia          True
# MOR            70        Morocco          True
# EG             45          Egypt          True

# %%
cpc = cars['cars_per_cap']
cpc
# Out:
# US     809
# AUS     31
# JPN    588
# IN      18
# RU     200
# MOR     70
# EG      45
# Name: cars_per_cap, dtype: int64

# %%
#cpc >10 and < 80
#create panda series which can be used to subset the DataFrame
between = np.logical_and(cpc > 10, cpc < 80)

print(type(between))
# Out:
# <class 'pandas.core.series.Series'>

# %%
#Subset the DF

medium = cars[between]

# %%
medium
# Out:
#      cars_per_cap    country  drives_right
# AUS            31  Australia         False
# IN             18      India         False
# MOR            70    Morocco          True
# EG             45      Egypt          True

# %% [markdown]
# # CH-4. LOOPS

# %% [markdown]
# ## 4.1 While Loop
#
#
# The while loop is like a repeated if statement. The code is executed over and over again, as long as the condition is True. Have another look at its recipe.
#
#         while condition :
#             expression
#
#
# WL is Numerically calculating model
#
# "repeating action until condition is met”
#
# Example:
#
#     ● Error starts at 50
#     ● Divide error by 4 on every run
#     ● Continue until error no longer > 1

# %% [markdown]
# **EXERCISE-1: Basic while loop**
#
# Create the variable offset with an initial value of 8.
#
# Code a while loop that keeps running as long as offset is not equal to 0.
#
# Inside the while loop:
# Print out the sentence "correcting...".
#
# Next, decrease the value of offset by 1. You can do this with offset = offset - 1.
# Finally, still within your loop, print out offset so you can see how it changes.

# %%
# Initialize offset
offset = 8

# Code the while loop
while offset != 0:
    print("correcting...")
    offset = offset-1
    print(offset)
# Out:
# correcting...
# 7
# correcting...
# 6
# correcting...
# 5
# correcting...
# 4
# correcting...
# 3
# correcting...
# 2
# correcting...
# 1
# correcting...
# 0

# %% [markdown]
# **EXERCISE-2: While Loop + Conditionals**
#
# Inside the while loop, complete the if-else statement:
#
# If offset is greater than zero, you should decrease offset by 1.
#
# Else, you should increase offset by 1.
#
# If you've coded things correctly, hitting Submit Answer should work this time.

# %%
# Initialize offset
offset = -6

# Code the while loop
while offset != 0 :
    print("correcting...")
    if offset>0 :
        offset = offset-1
    else : 
        offset = offset +1
    print(offset)
# Out:
# correcting...
# -5
# correcting...
# -4
# correcting...
# -3
# correcting...
# -2
# correcting...
# -1
# correcting...
# 0

# %% [markdown]
# ## 4.2 for loops
#
# ### 4.2.1 Loop over a list
#
# **Exercise-3: for Loops**
#
# Write a for loop that iterates over all elements of the areas list and prints out every element separately.

# %%
# areas list
areas = [11.25, 18.0, 20.0, 10.75, 9.50]

# Code the for loop
for x in areas:
    print(x)
# Out:
# 11.25
# 18.0
# 20.0
# 10.75
# 9.5

# %% [markdown]
# ### 4.2.2 Loop with Indexes and values
#
# Using a for loop to iterate over a list only gives you access to every list element in each run, one after the other.
#
# If you also want to access the index information, so where the list element you're iterating over is located, you can use `enumerate()`.
#
# `enumerate()` produces two values:
#
#     i. the index: placed on the first variable on the for loop
#     ii. and the value: placed on the second value on the variable list of for loop

# %% [markdown]
# **Exercise-4: Loop with index**
#
# Adapt the for loop in the sample code to use enumerate() and use two iterator variables.
#
# Update the print() statement so that on each run, a line of the form "room x: y" should be printed, where x is the index of the list element and y is the actual list element, i.e. the area.
#
# Make sure to print out this exact string, with the correct spacing.

# %%
# areas list
areas = [11.25, 18.0, 20.0, 10.75, 9.50]

# Change for loop to use enumerate() and update print()
for index, value in enumerate(areas) :
    print("room"+ str(index)+":"+str(value))
# Out:
# room0:11.25
# room1:18.0
# room2:20.0
# room3:10.75
# room4:9.5

# %% [markdown]
# Adapt the print() function in the for loop on the right so that the first printout becomes
#
# "room 1: 11.25", the second one "room 2: 18.0" and so on.

# %%
# areas list
areas = [11.25, 18.0, 20.0, 10.75, 9.50]

# Code the for loop
for index, area in enumerate(areas) :
    print("room " + str(index+1) + ": " + str(area))
# Out:
# room 1: 11.25
# room 2: 18.0
# room 3: 20.0
# room 4: 10.75
# room 5: 9.5

# %% [markdown]
# ### 4.2.3 Loop over list of lists
#
# Remember the house variable from the Intro to Python course?
#
# Have a look at its definition on the right. It's basically a list of lists, where each sublist contains the name and area of a room in your house.
#
# It's up to you to build a for loop from scratch this time!

# %% [markdown]
# **Exercise-5: Loop over list of lists**
#
# Write a for loop that goes through each sublist of house and prints out the x is y sqm, where x is the name of the room and y is the area of the room.

# %%
# house list of lists
house = [["hallway", 11.25], 
         ["kitchen", 18.0], 
         ["living room", 20.0], 
         ["bedroom", 10.75], 
         ["bathroom", 9.50]]
         
print("the "+house[1][0]+" is "+ str(house[1][1])+" sqm") 
print("the "+house[2][0]+" is "+ str(house[2][1])+" sqm")
print("the "+house[3][0]+" is "+ str(house[3][1])+" sqm")
print("the "+house[4][0]+" is "+ str(house[4][1])+" sqm")
# Out:
# the kitchen is 18.0 sqm
# the living room is 20.0 sqm
# the bedroom is 10.75 sqm
# the bathroom is 9.5 sqm

# %%
for x in house:
    print("the " + x[0] + " is " + str(x[1]) + " sqm")
# Out:
# the hallway is 11.25 sqm
# the kitchen is 18.0 sqm
# the living room is 20.0 sqm
# the bedroom is 10.75 sqm
# the bathroom is 9.5 sqm

# %% [markdown]
# We have already seen how loop works on strings and list.
#
# **The question is how about other data structures?**
#
# We can use the same forloop construct but the way how we define the sequence depends on the type of data structure at hand.
#
# Looping depends on the data structure (dictionary, or numpy array) at hand.
#
#
# To generate items we use `.items()` method for `dictionaries`.
#
# To generate items we use `np.nditer()` function for `numpyArrays`.

# %% [markdown]
# ### 4.2.4 Loop over dictionary
#
# we use `.items()` method
#
# In Python 3, we need the `items()` `method` to loop over a `dictionary`.

# %%
world = { "Germany":"Berlin", 
          "Ethiopia":"Addis",
          "Kenya":"Nairobi" }

for key, value in world.items() :
    print(key + " --> " + value)
# Out:
# Germany --> Berlin
# Ethiopia --> Addis
# Kenya --> Nairobi

# %% [markdown]
# **Exercise-6: LOOP OVER A DICTIONARY"**
#
# Write a for loop that goes through each key:value pair of europe.
#
# On each iteration, "the capital of x is y" should be printed out, where x is the key and y is the value of the pair.

# %%
# Definition of dictionary
europe = {'Germany':'Berlin', 'France':'Paris', 'Sweden':'Stockholm',
          'Norway':'Oslo' }
          
# Iterate over europe
for key, value in europe.items():
    print("the capital of "+ key +"is: "+ value)
# Out:
# the capital of Germanyis: Berlin
# the capital of Franceis: Paris
# the capital of Swedenis: Stockholm
# the capital of Norwayis: Oslo

# %% [markdown]
# ### 4.2.5 Loop over Numpy array: `.nditer(my_array)`
#
#  **For a 1D Numpy array:** - looping over all elements can be as simple as:
#
#     for x in my_array :
#         ...
#
# **For a 2D Numpy array:**  it is a bit `more complicated`.
#
# A 2D array is built up of multiple 1D arrays.
#
# To explicitly iterate over all separate elements of a `multi-dimensional array`, you'll need this syntax:
#
#     for x in np.nditer(my_array) :
#         ...

# %% [markdown]
# **EXERCISE -7: LOOP OVER 2D ARRAY**
#
# Import the numpy package under the local alias np.
#
# 1. Write a for loop that iterates over all elements in `np_height` and prints out `"x inches"` for each element, where `x is the value` in the array.
#
# 2. Write a for loop that visits every element of the **meas array** and prints it out.

# %%
# Import numpy as np
import numpy as np
np_height = [215, 195, 200, 215, 229, 240]
# For loop over np_height
for x in np_height:
    print(str(x)+" inches")
# Out:
# 215 inches
# 195 inches
# 200 inches
# 215 inches
# 229 inches
# 240 inches

# %%
import numpy as np
np_height = np.array([1.73, 1.68, 1.71, 1.89, 1.79])
np_weight = np.array([65.4, 59.2, 63.6, 88.4, 68.7])

#create 2D Array
meas = np.array([np_height, np_weight])
print(meas)
# Out:
# [[ 1.73  1.68  1.71  1.89  1.79]
#  [65.4  59.2  63.6  88.4  68.7 ]]

# %%
# loop that visits every element of the **meas array** and prints it out.

for val in np.nditer(meas):
    print(val)
# Out:
# 1.73
# 1.68
# 1.71
# 1.89
# 1.79
# 65.4
# 59.2
# 63.6
# 88.4
# 68.7

# %% [markdown]
# ### Recap Looping over:
#
# #### a Dictionary
# ● for key, val in my_dict.items()
#
# #### Numpy array
# ● for val in np.nditer(my_array) :

# %% [markdown]
# ### 4.2.6 Loop on Pandas Data frame

# %%
import pandas as pd
brics = pd.read_csv("brics.csv", index_col =0)
brics
# Out:
#          country    capital    area  population
# BR        Brazil   Brasilia   8.516      200.40
# RU        Russia     Moscow  17.100      143.50
# IN         India  New Delhi   3.286     1252.00
# CH         China    Beijing   9.597     1357.00
# SA  South Africa   Pretoria   1.221       52.98

# %% [markdown]
# **I. USING BASIC  FOR LOOP**
#
# Simply returns the `column names`

# %%
for x in brics:
    print(x)
# Out:
# country
# capital
# area
# population

# %% [markdown]
# Well, that's not bad.
#
# But what `we want is to iterate over the rows` most of the time.
#
# How do we do that??
#
#
# **II. ITERROWS METHOD**
#
# iterrows() method generates two pices of data for each iteration.
#
# 1. The `lebel` of the `row` and
#
# 2. The `actual data` in the row as a `panda series`

# %%
import pandas as pd
brics = pd.read_csv("brics.csv", index_col =0)

for label, row in brics.iterrows():
    print(label)
# Out:
# BR
# RU
# IN
# CH
# SA

# %%
for label, row in brics.iterrows():
    print(row, "\n")
# Out:
# country         Brazil
# capital       Brasilia
# area             8.516
# population       200.4
# Name: BR, dtype: object
#
# country       Russia
# capital       Moscow
# area            17.1
# population     143.5
# Name: RU, dtype: object
#
# country           India
# capital       New Delhi
# area              3.286
# population         1252
# Name: IN, dtype: object
#
# country         China
# capital       Beijing
# area            9.597
# population       1357
# Name: CH, dtype: object
#
# country       South Africa
# capital           Pretoria
# area                 1.221
# population           52.98
# Name: SA, dtype: object

# %%
import pandas as pd
brics = pd.read_csv("brics.csv", index_col =0)

for label, row in brics.iterrows():
    print(label)
    print(type(row), "\n")
# Out:
# BR
# <class 'pandas.core.series.Series'>
#
# RU
# <class 'pandas.core.series.Series'>
#
# IN
# <class 'pandas.core.series.Series'>
#
# CH
# <class 'pandas.core.series.Series'>
#
# SA
# <class 'pandas.core.series.Series'>

# %%
for label, row in cars.iterrows():
    print(label, "\n")
    print(row)
# Out:
# US
#
# cars_per_cap              809
# country         United States
# drives_right             True
# Name: US, dtype: object
# AUS
#
# cars_per_cap           31
# country         Australia
# drives_right        False
# Name: AUS, dtype: object
# JPN
#
# cars_per_cap      588
# country         Japan
# drives_right    False
# Name: JPN, dtype: object
# IN
#
# cars_per_cap       18
# country         India
# drives_right    False
# Name: IN, dtype: object
# RU
#
# cars_per_cap       200
# country         Russia
# drives_right      True
# Name: RU, dtype: object
# MOR
#
# cars_per_cap         70
# country         Morocco
# drives_right       True
# Name: MOR, dtype: object
# EG
#
# cars_per_cap       45
# country         Egypt
# drives_right     True
# Name: EG, dtype: object

# %% [markdown]
# #### Selective Print

# %%
import pandas as pd
brics = pd.read_csv("brics.csv", index_col =0)
brics
# Out:
#          country    capital    area  population
# BR        Brazil   Brasilia   8.516      200.40
# RU        Russia     Moscow  17.100      143.50
# IN         India  New Delhi   3.286     1252.00
# CH         China    Beijing   9.597     1357.00
# SA  South Africa   Pretoria   1.221       52.98

# %%
#selective print

for label, row in brics.iterrows():
    print(label,":",row["capital"])
# Out:
# BR : Brasilia
# RU : Moscow
# IN : New Delhi
# CH : Beijing
# SA : Pretoria

# %%
#selective print

for label, row in brics.iterrows():
    print(label,":",row["country"],":",row["capital"] )
# Out:
# BR : Brazil : Brasilia
# RU : Russia : Moscow
# IN : India : New Delhi
# CH : China : Beijing
# SA : South Africa : Pretoria

# %%
#selective print

for label, row in brics.iterrows():
    print(label,":",row["country"],":",row["capital"] )
# Out:
# BR : Brazil : Brasilia
# RU : Russia : Moscow
# IN : India : New Delhi
# CH : China : Beijing
# SA : South Africa : Pretoria

# %% [markdown]
# ### ADVANCED STUFF: using loop to modify our data frame
#
# Let's say we wanted **to add a column to our data frame** that indicates the number of characters for a country in a  country's column.
#
# `How do we add one more column in our data frame using loop?`

# %%
import pandas as pd
brics = pd.read_csv("brics.csv", index_col =0)

for label, row in brics.iterrows():
    brics.loc[label, "name_length"] = len(row["country"]) #creating a series on every iteration
    print(brics)
    print()
# Out:
#          country    capital    area  population  name_length
# BR        Brazil   Brasilia   8.516      200.40          6.0
# RU        Russia     Moscow  17.100      143.50          NaN
# IN         India  New Delhi   3.286     1252.00          NaN
# CH         China    Beijing   9.597     1357.00          NaN
# SA  South Africa   Pretoria   1.221       52.98          NaN
#
#          country    capital    area  population  name_length
# BR        Brazil   Brasilia   8.516      200.40          6.0
# RU        Russia     Moscow  17.100      143.50          6.0
# IN         India  New Delhi   3.286     1252.00          NaN
# CH         China    Beijing   9.597     1357.00          NaN
# SA  South Africa   Pretoria   1.221       52.98          NaN
#
#          country    capital    area  population  name_length
# BR        Brazil   Brasilia   8.516      200.40          6.0
# RU        Russia     Moscow  17.100      143.50          6.0
# IN         India  New Delhi   3.286     1252.00          5.0
# CH         China    Beijing   9.597     1357.00          NaN
# SA  South Africa   Pretoria   1.221       52.98          NaN
#
#          country    capital    area  population  name_length
# BR        Brazil   Brasilia   8.516      200.40          6.0
# RU        Russia     Moscow  17.100      143.50          6.0
# IN         India  New Delhi   3.286     1252.00          5.0
# CH         China    Beijing   9.597     1357.00          5.0
# SA  South Africa   Pretoria   1.221       52.98          NaN
#
#          country    capital    area  population  name_length
# BR        Brazil   Brasilia   8.516      200.40          6.0
# RU        Russia     Moscow  17.100      143.50          6.0
# IN         India  New Delhi   3.286     1252.00          5.0
# CH         China    Beijing   9.597     1357.00          5.0
# SA  South Africa   Pretoria   1.221       52.98         12.0

# %% [markdown]
# ## using `apply()` Function
#
# The above method is slow and computationally intensive for a big data.
#
# So we can do this using with out iteration using the apply() function.
#
# **WAY MORE EFFICIENT**

# %%
import pandas as pd
brics = pd.read_csv("brics.csv", index_col = 0)
brics["name_length"] = brics["country"].apply(len)
brics["data_type_capital"] = brics['capital'].apply(type)
brics
# Out:
#          country    capital    area  population  name_length data_type_capital
# BR        Brazil   Brasilia   8.516      200.40            6     <class 'str'>
# RU        Russia     Moscow  17.100      143.50            6     <class 'str'>
# IN         India  New Delhi   3.286     1252.00            5     <class 'str'>
# CH         China    Beijing   9.597     1357.00            5     <class 'str'>
# SA  South Africa   Pretoria   1.221       52.98           12     <class 'str'>

# %% [markdown]
# **EXERCISE-8: Loop over DataFrame**
#
# Write a for loop that iterates over the `rows of cars` and on each iteration perform two print() calls:
#
# one to print out the row label and
#
# one to print out all of the rows contents.

# %%
import pandas as pd
cars = pd.read_csv("cars.csv", index_col =0)
cars
# Out:
#      cars_per_cap        country  drives_right
# US            809  United States          True
# AUS            31      Australia         False
# JPN           588          Japan         False
# IN             18          India         False
# RU            200         Russia          True
# MOR            70        Morocco          True
# EG             45          Egypt          True

# %%
for label, row in cars.iterrows():
    print(label, "\n")
    print(row, "\n")
    print("==================================")
# Out:
# US
#
# cars_per_cap              809
# country         United States
# drives_right             True
# Name: US, dtype: object
#
# ==================================
# AUS
#
# cars_per_cap           31
# country         Australia
# drives_right        False
# Name: AUS, dtype: object
#
# ==================================
# JPN
#
# cars_per_cap      588
# country         Japan
# drives_right    False
# Name: JPN, dtype: object
#
# ==================================
# IN
#
# cars_per_cap       18
# country         India
# drives_right    False
# Name: IN, dtype: object
#
# ==================================
# RU
#
# cars_per_cap       200
# country         Russia
# drives_right      True
# Name: RU, dtype: object
#
# ==================================
# MOR
#
# cars_per_cap         70
# country         Morocco
# drives_right       True
# Name: MOR, dtype: object
#
# ==================================
# EG
#
# cars_per_cap       45
# country         Egypt
# drives_right     True
# Name: EG, dtype: object
#
# ==================================

# %% [markdown]
# **EXERCISE-9: Loop over DataFrame: Selective Print**
#
# Using the iterators lab and row, adapt the code in the for loop such that:
#
#     the first iteration prints out "US: 809",
#     the second iteration "AUS: 731",
#     and so on.
#
#
# The output should be in the form
#
#     "country: cars_per_cap".
#
# Make sure to print out this exact string (with the correct spacing).
#
# You can use `str()` to convert your integer data to a string so that you can print it in conjunction with the `country label`.

# %%
import pandas as pd
cars = pd.read_csv("cars.csv", index_col =0)
cars
# Out:
#      cars_per_cap        country  drives_right
# US            809  United States          True
# AUS            31      Australia         False
# JPN           588          Japan         False
# IN             18          India         False
# RU            200         Russia          True
# MOR            70        Morocco          True
# EG             45          Egypt          True

# %%
for label, row in cars.iterrows():
    print(label+" :  "+str(row["cars_per_cap"]))
# Out:
# US :  809
# AUS :  31
# JPN :  588
# IN :  18
# RU :  200
# MOR :  70
# EG :  45

# %% [markdown]
# **EXERCISE-10: Loop over DataFrame: Add a new Column**
#
# Use a for loop `to add a new column`,
#
#     named COUNTRY, that contains a uppercase version of the country names in the "country" col.
#     You can use the string method upper() for this.
#
# To see if your code worked, print out cars. Don't indent this code, so that it's not part of the for loop.

# %%
import pandas as pd
cars = pd.read_csv("cars.csv", index_col =0)
cars
# Out:
#      cars_per_cap        country  drives_right
# US            809  United States          True
# AUS            31      Australia         False
# JPN           588          Japan         False
# IN             18          India         False
# RU            200         Russia          True
# MOR            70        Morocco          True
# EG             45          Egypt          True

# %%
for label, row in cars.iterrows():
    cars.loc[label, "COUNTRY"] = row["country"].upper()#creating a series on every iteration
print(cars)
# Out:
#      cars_per_cap        country  drives_right        COUNTRY
# US            809  United States          True  UNITED STATES
# AUS            31      Australia         False      AUSTRALIA
# JPN           588          Japan         False          JAPAN
# IN             18          India         False          INDIA
# RU            200         Russia          True         RUSSIA
# MOR            70        Morocco          True        MOROCCO
# EG             45          Egypt          True          EGYPT

# %%
import pandas as pd
cars = pd.read_csv("cars.csv", index_col = 0)
cars["COUNTRY"] = cars["country"].apply(str.upper)
print(cars)
# Out:
#      cars_per_cap        country  drives_right        COUNTRY
# US            809  United States          True  UNITED STATES
# AUS            31      Australia         False      AUSTRALIA
# JPN           588          Japan         False          JAPAN
# IN             18          India         False          INDIA
# RU            200         Russia          True         RUSSIA
# MOR            70        Morocco          True        MOROCCO
# EG             45          Egypt          True          EGYPT

# %% [markdown]
# # CH-5. RANDOM NUMBERS
#
# ### Random float
#
# **Randomness** has many uses in science, art, statistics, cryptography, gaming, gambling, and other fields.
#
# You're going to use randomness to simulate a game.
#
# All the functionality you need is contained in the `random package`, a `sub-package` of `numpy`.
#
# In this exercise, you'll be using two functions from this package:
#
# `seed()`: sets the random seed, so that your results are reproducible between simulations. As an argument, it takes an integer of your choosing.
#
#
# If you call the function, no output will be generated.
#
# `rand()`: if you don't specify any arguments, it generates a random float between zero and one.

# %%
# Import numpy as np
import numpy as np

# Set the seed
np.random.seed(2)

# Generate and print random float
np.random.rand()
# Out:
# 0.43599490214200376

# %%
#generate 10 random numbers using 10 seeds 0 - 9
for x in range(10):
    np.random.seed(x)
    l = np.random.rand()
    print(l)
# Out:
# 0.5488135039273248
# 0.417022004702574
# 0.43599490214200376
# 0.5507979025745755
# 0.9670298390136767
# 0.22199317108973948
# 0.8928601514360016
# 0.07630828937395717
# 0.8734294027918162
# 0.010374153885699955

# %% [markdown]
# ### Roll the dice
#
# In the previous exercise, you used `rand()`, that generates a random float between 0 and 1.
#
# As Filip explained in the video you can just as well use `randint()`, also a function of the random package, to generate integers randomly.
#
# The following call generates the integer 4, 5, 6 or 7 randomly. 8 is not included.
#
#     import numpy as np
#     np.random.randint(4, 8)
#
# Numpy has already been imported as np and a seed has been set. Can you roll some dice?

# %% [markdown]
# Use `randint()` with the appropriate arguments to randomly generate the integer 1, 2, 3, 4, 5 or 6. This simulates a dice. Print it out.

# %%
# Import numpy and set seed
import numpy as np
np.random.seed(123)

# Use randint() to simulate a dice
print(np.random.randint(1,7))
# Out:
# 6

# %% [markdown]
# Repeat the outcome to see if the second throw is different. Again, print out the result.

# %%
# Use randint() again
print(np.random.randint(1,7))
# Out:
# 3

# %% [markdown]
# ### Determine your next move
#
# In the Empire State Building bet, your next move depends on the number of eyes you throw with the dice. We can perfectly code this with an `if-elif-else` construct!
#
# The sample code assumes that you're currently at `step 50`.
#
# Can you fill in the missing pieces to finish the script? numpy is already imported as np and the seed has been set to 123, so you don't have to worry about that anymore.

# %%
import numpy as np

# %%
step = 50

# %%
# Roll the dice. Use randint() to create the variable dice.

dice = np.random.randint(1,7)

# %% [markdown]
# Finish the if-elif-else construct by replacing ___:
#
#     If dice is 1 or 2, you go one step down.
#     if dice is 3, 4 or 5, you go one step up.
#     Else, you throw the dice again. The number of eyes is the number of steps you go up.

# %%
if dice <= 2 :
    step = step - 1
elif dice <=5 :
    step = step +1
else :
    step = step + np.random.randint(1,7)

# %% [markdown]
# Print out dice and step. Given the value of dice, was step updated correctly?

# %%
# Print out dice and step
print(dice, step)
# Out:
# 5 51

# %% [markdown]
# ### Heads or Tails: Random Walk
#
# Random Walk: code that determines the next step based on the previous step

# %%
import numpy as np
np.random.seed(123)
tails = [0]
for x in range(10) :
    coin = np.random.randint(0, 2)
    tails.append(tails[x] + coin)
print(tails)
# Out:
# [0, 0, 1, 1, 1, 1, 1, 1, 2, 3, 3]

# %% [markdown]
# ### The next step
#
# Before, you have already written Python code that determines the next step based on the previous step.
#
# Now it's time to put this code inside a for loop so that we can simulate a random walk.

# %%
# Numpy is imported, seed is set
import numpy as np
np.random.seed(123)

# Initialize random_walk: Make a list random_walk that contains the first step, 
#which is the integer 0.

random_walk = [0]

# %%
for x in range(100) :
    # Set step: last element in random_walk
    step = random_walk[-1]

    # Roll the dice
    dice = np.random.randint(1,7)

    # Determine next step
    if dice <= 2:
        step = step - 1
    elif dice <= 5:
        step = step + 1
    else:
        step = step + np.random.randint(1,7)

    # append next_step to random_walk
    random_walk.append(step)

# %%
# Print random_walk
print(random_walk)
# Out:
# [0, 3, 4, 5, 4, 5, 6, 7, 6, 5, 4, 3, 2, 1, 0, -1, 0, 5, 4, 3, 4, 3, 4, 5, 6, 7, 8, 7, 8, 7, 8, 9, 10, 11, 10, 14, 15, 14, 15, 14, 15, 16, 17, 18, 19, 20, 21, 24, 25, 26, 27, 32, 33, 37, 38, 37, 38, 39, 38, 39, 40, 42, 43, 44, 43, 42, 43, 44, 43, 42, 43, 44, 46, 45, 44, 45, 44, 45, 46, 47, 49, 48, 49, 50, 51, 52, 53, 52, 51, 52, 51, 52, 53, 52, 55, 56, 57, 58, 57, 58, 59]

# %% [markdown]
# ### How low can you go?
#
# Things are shaping up nicely!
#
# You already have code that calculates your location in the Empire State Building after 100 dice throws.
#
# However, there's something we haven't thought about - you can't go below 0!
#
# A typical way to solve problems like this is by using `max()`.
#
# If you pass `max()` two arguments, the biggest one gets returned. For example, to make sure that a variable x never goes below 10 when you decrease it, you can use:
#
# `x = max(10, x - 1)`

# %%
# Numpy is imported, seed is set
import numpy as np
np.random.seed(123)

# Initialize random_walk
random_walk = [0]

for x in range(100) :
    step = random_walk[-1]
    dice = np.random.randint(1,7)

    if dice <= 2:
        # Replace below: use max to make sure step can't go below 0
        step = max(0, step-1)
    elif dice <= 5:
        step = step + 1
    else:
        step = step + np.random.randint(1,7)

    random_walk.append(step)

print(random_walk)
# Out:
# [0, 3, 4, 5, 4, 5, 6, 7, 6, 5, 4, 3, 2, 1, 0, 0, 1, 6, 5, 4, 5, 4, 5, 6, 7, 8, 9, 8, 9, 8, 9, 10, 11, 12, 11, 15, 16, 15, 16, 15, 16, 17, 18, 19, 20, 21, 22, 25, 26, 27, 28, 33, 34, 38, 39, 38, 39, 40, 39, 40, 41, 43, 44, 45, 44, 43, 44, 45, 44, 43, 44, 45, 47, 46, 45, 46, 45, 46, 47, 48, 50, 49, 50, 51, 52, 53, 54, 53, 52, 53, 52, 53, 54, 53, 56, 57, 58, 59, 58, 59, 60]

# %% [markdown]
# ### Visualize the walk
#
# Let's visualize this random walk!
#
# Remember how you could use `matplotlib` to build a line plot?
#
#     import matplotlib.pyplot as plt
#     plt.plot(x, y)
#     plt.show()
#
# The first list you pass is mapped onto the x axis and the second list is mapped onto the y axis.
#
# If you pass only one argument, Python will know what to do and will use the index of the list to map onto the x axis, and the values in the list onto the y axis.

# %%
import matplotlib.pyplot as plt

#Use plt.plot() to plot random_walk.

# Plot random_walk
plt.plot(random_walk)

# Show the plot
plt.show()

# %%
# numpy and matplotlib imported, seed set.
import numpy as np
np.random.seed(123)
# initialize and populate all_walks
all_walks = []
for i in range(10) :
    random_walk = [0]
    for x in range(100) :
        step = random_walk[-1]
        dice = np.random.randint(1,7)
        if dice <= 2:
            step = max(0, step - 1)
        elif dice <= 5:
            step = step + 1
        else:
            step = step + np.random.randint(1,7)
        random_walk.append(step)
    all_walks.append(random_walk)

# Convert all_walks to Numpy array: np_aw
np_aw = np.array(all_walks)

# Plot np_aw and show
plt.plot(np_aw)
plt.show()
# Clear the figure
plt.clf()

# Transpose np_aw: np_aw_t
np_aw_t = np.transpose(np_aw)

# Plot np_aw_t and show
plt.plot(np_aw_t)
plt.show()
